# %%
pip install matplotlib
# Out:
# ...
#
# ...

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
df_grades = pd.read_csv("superstore.csv")
df_grades
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market  记录数               Order.Date  \
# 0      Lycoris Saunders       0.0     US    1  2011-01-07 00:00:00.000
# ...

# %%
import matplotlib.pyplot as plt
X_values =  [0, 1, 2, 3, 4, 5]
Y_values = [0, 1, 4, 9, 16, 25]
plt.title('Line Graph')
plt.plot(X_values, Y_values)
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.lineplot(data = df_grades, x='Quantity', y='Shipping.Cost')
plt.title('Shipping Cost per Quantity')
plt.show()
# Out:
# E:\jupiter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\jupiter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8, 6))

sns.lineplot(data = df_grades, x='Discount', y='Quantity')
plt.title('Quantity purchased per Discount')
# Out:
# E:\jupiter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\jupiter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Quantity purchased per Discount')

# %%
plt.figure(figsize=(15, 6))
sns.barplot(x='Region', y='Quantity', data= df_grades)
plt.title('Quantity purchased per Region')
plt.show()

# %%
mean_sales_by_category = df_grades.groupby('Discount')['Sales'].mean()
plt.figure(figsize=(10, 80))
plt.pie(mean_sales_by_category, labels=mean_sales_by_category.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Mean Sales by Discount')
# Out:
# Text(0.5, 1.0, 'Mean Sales by Discount')

# %%
product_counts = df_grades['Product.Name'].value_counts()
top_product = product_counts.idxmax()
highest_count = product_counts.max()

print(f"The products with names {top_product} was bought the most, with a count of {highest_count} as assigned to each.")
plt.figure(figsize=(20, 6))
sns.barplot(x=product_counts.index[:6], y=product_counts.values[:6], palette="viridis")
plt.xlabel('Product ID')
plt.ylabel('Number of Purchases')
plt.title('Top 10 Products Bought the Most')
# Out:
# The products with names Staples was bought the most, with a count of 227 as assigned to each.
# Text(0.5, 1.0, 'Top 10 Products Bought the Most')

# %%
total_sales_by_product = df_grades.groupby('Product.Name')['Sales'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Product.Name', y='Sales', data=total_sales_by_product)
plt.xlabel('Product Name')
plt.ylabel('Total Sales')
plt.title('Correlation between Products and Sales')
plt.show()

# %%
df_grades['Order.Date'] = pd.to_datetime(df_grades['Order.Date'])
order_counts_by_date = df_grades['Order.Date'].value_counts()
date_with_highest_orders = order_counts_by_date.idxmax()
highest_orders_count = order_counts_by_date.max()
print(f"The date with the highest number of orders is {date_with_highest_orders} with {highest_orders_count} orders.")
plt.figure(figsize=(12, 6))
sns.barplot(x=order_counts_by_date.index[:10], y=order_counts_by_date.values[:10], palette="viridis")
plt.xlabel('Order Date')
plt.ylabel('Number of Orders')
plt.title('Number of Orders by Date')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# The date with the highest number of orders is 2014-06-18 00:00:00 with 135 orders.
